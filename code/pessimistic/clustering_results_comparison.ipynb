# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# # tf_idf
## bezeichnung
v_measures_df_tf_idf_bezeichnung = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_tfidf_bezeichnung_df.csv')
homogeneity_measures_df_tf_idf_bezeichnung = pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_tfidf_bezeichnung_df.csv')
completness_measures_df_tf_idf_bezeichnung = pd.read_csv('calculated_files/evaluation_metric_dfs/completeness_measures_tfidf_bezeichnung_df.csv')

## webbezeichnung
v_measures_df_tf_idf_webbezeichnung = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_tfidf_webbezeichnung_df.csv')
homogeneity_measures_df_tf_idf_webbezeichnung = pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_tfidf_webbezeichnung_df.csv')
completness_measures_df_tf_idf_webbezeichnung = pd.read_csv('calculated_files/evaluation_metric_dfs/completeness_measures_tfidf_webbezeichnung_df.csv')

## detailinformation
v_measures_df_tf_idf_detailinformation = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_df_tf_idf_detailinformation_minibatchkmeans.csv')
homogeneity_measures_df_tf_idf_detailinformation =  pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_tf_idf_detailinformation_minibatchkmeans.csv')
completness_measures_df_tf_idf_detailinformation = pd.read_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_tf_idf_detailinformation_minibatchkmeans.csv')


## lieferantendetailinformation
v_measures_df_tf_idf_lieferantendetailinformation = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_df_tf_idf_lieferantendetailinformation.csv')
homogeneity_measures_df_tf_idf_lieferantendetailinformation = pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_tf_idf_lieferantendetailinformation.csv')
completness_measures_df_tf_idf_lieferantendetailinformation = pd.read_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_tf_idf_lieferantendetailinformation.csv')

## all
v_measures_df_tf_idf_all_minibatchkmeans = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_df_tf_idf_all_minibatchkmeans.csv')
homogeneity_measures_df_tf_idf_all_minibatchkmeans = pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_tf_idf_all_minibatchkmeans.csv')
completness_measures_df_tf_idf_all_minibatchkmeans = pd.read_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_tf_idf_all_minibatchkmeans.csv')

# v_measures_df_tf_idf_all_minibatchkmeans.to_csv('calculated_files/evaluation_metric_dfs/v_measures_df_tf_idf_all_minibatchkmeans.csv', index=False)
# homogeneity_measures_df_tf_idf_all_minibatchkmeans.to_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_tf_idf_all_minibatchkmeans.csv', index=False)
# completness_measures_df_tf_idf_all_minibatchkmeans.to_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_tf_idf_all_minibatchkmeans.csv', index=False)



# word embedding
# distil v1
v_measures_df_distil_v1pd = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_df_distil_v1.csv')
homogeneity_measures_df_distil_v1pd = pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_distil_v1.csv')
completness_measures_df_distil_v1pd = pd.read_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_distil_v1.csv')

# distil v2
v_measures_df_distil_v2pd = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_df_distil_v2.csv')
homogeneity_measures_df_distil_v2pd = pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_distil_v2.csv')
completness_measures_df_distil_v2pd = pd.read_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_distil_v2.csv')

# paraph miniLM
v_measures_df_paraph_miniLMpd = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_df_paraph_miniLM.csv')
homogeneity_measures_df_paraph_miniLMpd = pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_paraph_miniLM.csv')
completness_measures_df_paraph_miniLMpd = pd.read_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_paraph_miniLM.csv')

# paraph mpnet
v_measures_df_paraph_mpnetpd = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_df_paraph_mpnet.csv')
homogeneity_measures_df_paraph_mpnetpd = pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_paraph_mpnet.csv')
completness_measures_df_paraph_mpnetpd = pd.read_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_paraph_mpnet.csv')


# One Hot Encoding
v_measures_df_ohe_key = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_df_ohe_key.csv')
homogeneity_measures_df_ohe_key= pd.read_csv('calculated_files/evaluation_metric_dfs/homogeneity_measures_df_ohe_key.csv')
completness_measures_df_ohe_key = pd.read_csv('calculated_files/evaluation_metric_dfs/completness_measures_df_ohe_key.csv')



###### SSE

# TF-IDF

sse_bezeichnung = np.load('calculated_files/sse/sse_tfidf_bezeichnung.npy', allow_pickle=True)
sse_webbezeichnung = np.load('calculated_files/sse/sse_tfidf_webbezeichnung.npy', allow_pickle=True)
sse_detail = np.load('calculated_files/sse/sse_detail.npy', allow_pickle=True)
sse_lieferanten = np.load('calculated_files/sse/sse_lieferanten.npy', allow_pickle=True)
sse_all = np.load('calculated_files/sse/tfidf_sse_all.npy', allow_pickle=True)

# Sentence Transformers, SBERT
sse_scaled_distil1 = np.load('calculated_files/sse/WE_distil1.npy', allow_pickle=True)
sse_scaled_distil2 = np.load('calculated_files/sse/WE_distil2.npy', allow_pickle=True)
sse_scaled_miniLM = np.load('calculated_files/sse/WE_miniLM.npy', allow_pickle=True)
sse_scaled_mpnet = np.load('calculated_files/sse/WE_mpnet.npy', allow_pickle=True)

# OHE
sse_OHE = np.load('calculated_files/sse/sse_ohe.npy', allow_pickle=True)


####### HDBSCAN SBERT
# distil 1
v_measures_df_paraph_distil1 = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_dbscan_distil1.csv')
homogeneity_measures_df_paraph_distil1 = pd.read_csv('calculated_files/evaluation_metric_dfs/homogene\ity_measures_dbscan_distil1.csv')
completness_measures_df_paraph_distil1 = pd.read_csv('calculated_files/evaluation_metric_dfs/completeness_measures_dbscan_distil1.csv')

# distil 2
v_measures_df_paraph_distil2 = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_dbscan_distil2.csv')
homogeneity_measures_df_paraph_distil2 = pd.read_csv('calculated_files/evaluation_metric_dfs/homogene\ity_measures_dbscan_distil2.csv')
completness_measures_df_paraph_distil2 = pd.read_csv('calculated_files/evaluation_metric_dfs/completeness_measures_dbscan_distil2.csv')


# miniLM
v_measures_df_paraph_minlm = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_dbscan_minilm.csv')
homogeneity_measures_df_paraph_minilm = pd.read_csv('calculated_files/evaluation_metric_dfs/homogene\ity_measures_dbscan_minilm.csv')
completness_measures_df_paraph_minilm = pd.read_csv('calculated_files/evaluation_metric_dfs/completeness_measures_dbscan_minilm.csv')

# mpnet
v_measures_df_mpnet = pd.read_csv('calculated_files/evaluation_metric_dfs/v_measures_dbscan_mpnet.csv')
homogeneity_measures_df_mpnet = pd.read_csv('calculated_files/evaluation_metric_dfs/homogene\ity_measures_dbscan_mpnet.csv')
completness_measures_df_mpnet = pd.read_csv('calculated_files/evaluation_metric_dfs/completeness_measures_dbscan_mpnet.csv')

# %% [markdown]
# # plotting all the kmeans plots together
# In the cell below that, they're displayed separately.

# %%
# plt.subplots(3, 3, figsize=(12, 12))
fig, axs =  plt.subplots(10, 3, figsize=(15, 20)) # 3 * 9


# TF-IDF

## Bezeichnung
ax = axs[0, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_4'], 'c')
ax.set_set_title('V-measure TF-IDF Bezeichnung')
ax = axs[0, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF Bezeichnung')
ax = axs[0, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_bezeichnung['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_bezeichnung['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_bezeichnung['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_bezeichnung['layer_4'], 'c')
ax.set_title('Completeness TF-IDF Bezeichnung')

## Webbezeichnung
ax = axs[1, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_webbezeichnung['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_webbezeichnung['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_webbezeichnung['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_webbezeichnung['layer_4'], 'c')
ax.set_title('V-measure TF-IDF Webbezeichnung')
ax = axs[1, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_webbezeichnung['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_webbezeichnung['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_webbezeichnung['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_webbezeichnung['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF Webbezeichnung')
ax = axs[1, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_webbezeichnung['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_webbezeichnung['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_webbezeichnung['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_webbezeichnung['layer_4'], 'c')
ax.set_title('Completeness TF-IDF Webbezeichnung')

## DetailInformation
ax = axs[2, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_detailinformation['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_detailinformation['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_detailinformation['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_detailinformation['layer_4'], 'c')
ax.set_title('V-measure TF-IDF DetailInformation')
ax = axs[2, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_detailinformation['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_detailinformation['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_detailinformation['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_detailinformation['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF DetailInformation')
ax = axs[2, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_detailinformation['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_detailinformation['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_detailinformation['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_detailinformation['layer_4'], 'c')
ax.set_title('Completeness TF-IDF DetailInformation')


## LieferantenDetailinformation
ax = axs[3, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_lieferantendetailinformation['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_lieferantendetailinformation['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_lieferantendetailinformation['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_lieferantendetailinformation['layer_4'], 'c')
ax.set_title('V-measure TF-IDF LieferantenDetailinformation')
ax = axs[3, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_lieferantendetailinformation['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_lieferantendetailinformation['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_lieferantendetailinformation['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_lieferantendetailinformation['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF LieferantenDetailinformation')
ax = axs[3, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_lieferantendetailinformation['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_lieferantendetailinformation['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_lieferantendetailinformation['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_lieferantendetailinformation['layer_4'], 'c')
ax.set_title('Completeness TF-IDF LieferantenDetailinformation')

## All four columns
ax = axs[4, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_all_minibatchkmeans['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_all_minibatchkmeans['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_all_minibatchkmeans['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_all_minibatchkmeans['layer_4'], 'c')
ax.set_title('V-measure TF-IDF All')
ax = axs[4, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_all_minibatchkmeans['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_all_minibatchkmeans['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_all_minibatchkmeans['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_all_minibatchkmeans['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF All')
ax = axs[4, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_all_minibatchkmeans['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_all_minibatchkmeans['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_all_minibatchkmeans['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_all_minibatchkmeans['layer_4'], 'c')
ax.set_title('Completeness TF-IDF All')

# Sentence Transformers, Word Embedding
## Distil V1
ax = axs[5, 0]
ax.plot(range(1, 150, 5), v_measures_df_distil_v1pd['layer_1'], 'r', range(1, 150, 5), v_measures_df_distil_v1pd['layer_2'], 'b', range(1, 150, 5), v_measures_df_distil_v1pd['layer_3'], 'g', range(1, 150, 5), v_measures_df_distil_v1pd['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Distil V1')
ax = axs[5, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_distil_v1pd['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_distil_v1pd['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_distil_v1pd['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_distil_v1pd['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Distil V1')
ax = axs[5, 2]
ax.plot(range(1, 150, 5), completness_measures_df_distil_v1pd['layer_1'], 'r', range(1, 150, 5), completness_measures_df_distil_v1pd['layer_2'], 'b', range(1, 150, 5), completness_measures_df_distil_v1pd['layer_3'], 'g', range(1, 150, 5), completness_measures_df_distil_v1pd['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Distil V1')

## Distil V2
ax = axs[6, 0]
ax.plot(range(1, 150, 5), v_measures_df_distil_v2pd['layer_1'], 'r', range(1, 150, 5), v_measures_df_distil_v2pd['layer_2'], 'b', range(1, 150, 5), v_measures_df_distil_v2pd['layer_3'], 'g', range(1, 150, 5), v_measures_df_distil_v2pd['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Distil V2')
ax = axs[6, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_distil_v2pd['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_distil_v2pd['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_distil_v2pd['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_distil_v2pd['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Distil V2')
ax = axs[6, 2]
ax.plot(range(1, 150, 5), completness_measures_df_distil_v2pd['layer_1'], 'r', range(1, 150, 5), completness_measures_df_distil_v2pd['layer_2'], 'b', range(1, 150, 5), completness_measures_df_distil_v2pd['layer_3'], 'g', range(1, 150, 5), completness_measures_df_distil_v2pd['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Distil V2')

## Paraph MiniLM
ax = axs[7, 0]
ax.plot(range(1, 150, 5), v_measures_df_paraph_miniLMpd['layer_1'], 'r', range(1, 150, 5), v_measures_df_paraph_miniLMpd['layer_2'], 'b', range(1, 150, 5), v_measures_df_paraph_miniLMpd['layer_3'], 'g', range(1, 150, 5), v_measures_df_paraph_miniLMpd['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Paraph MiniLM')
ax = axs[7, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_paraph_miniLMpd['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_paraph_miniLMpd['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_paraph_miniLMpd['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_paraph_miniLMpd['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Paraph MiniLM')
ax = axs[7, 2]
ax.plot(range(1, 150, 5), completness_measures_df_paraph_miniLMpd['layer_1'], 'r', range(1, 150, 5), completness_measures_df_paraph_miniLMpd['layer_2'], 'b', range(1, 150, 5), completness_measures_df_paraph_miniLMpd['layer_3'], 'g', range(1, 150, 5), completness_measures_df_paraph_miniLMpd['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Paraph MiniLM')

## Paraph MPNet
ax = axs[8, 0]
ax.plot(range(1, 150, 5), v_measures_df_paraph_mpnetpd['layer_1'], 'r', range(1, 150, 5), v_measures_df_paraph_mpnetpd['layer_2'], 'b', range(1, 150, 5), v_measures_df_paraph_mpnetpd['layer_3'], 'g', range(1, 150, 5), v_measures_df_paraph_mpnetpd['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Paraph MPNet')
ax = axs[8, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_paraph_mpnetpd['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_paraph_mpnetpd['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_paraph_mpnetpd['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_paraph_mpnetpd['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Paraph MPNet')
ax = axs[8, 2]
ax.plot(range(1, 150, 5), completness_measures_df_paraph_mpnetpd['layer_1'], 'r', range(1, 150, 5), completness_measures_df_paraph_mpnetpd['layer_2'], 'b', range(1, 150, 5), completness_measures_df_paraph_mpnetpd['layer_3'], 'g', range(1, 150, 5), completness_measures_df_paraph_mpnetpd['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Paraph MPNet')

# One Hot Encoding
ax = axs[9, 0]
ax.plot(range(1, 150, 5), v_measures_df_ohe_key['layer_1'], 'r', range(1, 150, 5), v_measures_df_ohe_key['layer_2'], 'b', range(1, 150, 5), v_measures_df_ohe_key['layer_3'], 'g', range(1, 150, 5), v_measures_df_ohe_key['layer_4'], 'c')
ax.set_title('V-measure OHE', pad=10)
ax.set_xlabel("Number of K's")
ax = axs[9, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_ohe_key['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_ohe_key['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_ohe_key['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_ohe_key['layer_4'], 'c')
ax.set_title('Homogeneity OHE', pad=10)
ax.set_xlabel("Number of K's")
ax = axs[9, 2]
ax.plot(range(1, 150, 5), completness_measures_df_ohe_key['layer_1'], 'r', range(1, 150, 5), completness_measures_df_ohe_key['layer_2'], 'b', range(1, 150, 5), completness_measures_df_ohe_key['layer_3'], 'g', range(1, 150, 5), completness_measures_df_ohe_key['layer_4'], 'c')
ax.set_title('Completeness OHE', pad=10)
ax.set_xlabel("Number of K's")


# plt.show()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

labels = ["Layer_1", "Layer_2", "Layer_3", "Layer_4"] 
fig.legend(ax, labels=labels, 
           loc="upper right") 

y=np.arange(0, 1, step=0.1)
for i in range(10):
    for j in range(3):
        axs[i, j].axvline(x = 19, color = 'red', linestyle = '--', alpha = 0.5)
        axs[i, j].axvline(x = 124, color = 'blue', linestyle = '--', alpha = 0.5)
        plt.yticks(y)
        # axs[i, j].axvline(x = 439, color = 'red', linestyle = '--', alpha = 0.5)
    
# ax.axvline(x = 19, color = 'red', linestyle = '--', alpha = 0.5)

# y=np.linspace(0, 1)

plt.yticks(y)
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       8 ax = axs[0, 0]
#       9 ax.plot(range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_4'], 'c')
# ---> 10 ax.set_set_title('V-measure TF-IDF Bezeichnung')
#      11 ax = axs[0, 1]
#      12 ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_4'], 'c')
#
# AttributeError: 'Axes' object has no attribute 'set_set_title'

# %% [markdown]
# # TF-IDF

# %%
# plt.subplots(3, 3, figsize=(12, 12))
# fig, axs =  plt.subplots(10, 3, figsize=(15, 10)) # 3 * 9
fig, axs =  plt.subplots(5, 3, figsize=(15, 10)) # 3 * 9


# TF-IDF

## Bezeichnung
ax = axs[0, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_bezeichnung['layer_4'], 'c')
ax.set_title('V-measure TF-IDF Bezeichnung')
ax = axs[0, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_bezeichnung['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF Bezeichnung')
ax = axs[0, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_bezeichnung['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_bezeichnung['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_bezeichnung['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_bezeichnung['layer_4'], 'c')
ax.set_title('Completeness TF-IDF Bezeichnung')

## Webbezeichnung
ax = axs[1, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_webbezeichnung['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_webbezeichnung['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_webbezeichnung['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_webbezeichnung['layer_4'], 'c')
ax.set_title('V-measure TF-IDF Webbezeichnung')
ax = axs[1, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_webbezeichnung['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_webbezeichnung['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_webbezeichnung['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_webbezeichnung['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF Webbezeichnung')
ax = axs[1, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_webbezeichnung['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_webbezeichnung['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_webbezeichnung['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_webbezeichnung['layer_4'], 'c')
ax.set_title('Completeness TF-IDF Webbezeichnung')

## DetailInformation
ax = axs[2, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_detailinformation['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_detailinformation['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_detailinformation['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_detailinformation['layer_4'], 'c')
ax.set_title('V-measure TF-IDF DetailInformation')
ax = axs[2, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_detailinformation['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_detailinformation['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_detailinformation['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_detailinformation['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF DetailInformation')
ax = axs[2, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_detailinformation['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_detailinformation['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_detailinformation['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_detailinformation['layer_4'], 'c')
ax.set_title('Completeness TF-IDF DetailInformation')


## LieferantenDetailinformation
ax = axs[3, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_lieferantendetailinformation['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_lieferantendetailinformation['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_lieferantendetailinformation['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_lieferantendetailinformation['layer_4'], 'c')
ax.set_title('V-measure TF-IDF LieferantenDetailinformation')
ax = axs[3, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_lieferantendetailinformation['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_lieferantendetailinformation['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_lieferantendetailinformation['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_lieferantendetailinformation['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF LieferantenDetailinformation')
ax = axs[3, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_lieferantendetailinformation['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_lieferantendetailinformation['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_lieferantendetailinformation['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_lieferantendetailinformation['layer_4'], 'c')
ax.set_title('Completeness TF-IDF LieferantenDetailinformation')

## All four columns
ax = axs[4, 0]
ax.plot(range(1, 150, 5), v_measures_df_tf_idf_all_minibatchkmeans['layer_1'], 'r', range(1, 150, 5), v_measures_df_tf_idf_all_minibatchkmeans['layer_2'], 'b', range(1, 150, 5), v_measures_df_tf_idf_all_minibatchkmeans['layer_3'], 'g', range(1, 150, 5), v_measures_df_tf_idf_all_minibatchkmeans['layer_4'], 'c')
ax.set_title('V-measure TF-IDF All')
ax = axs[4, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_tf_idf_all_minibatchkmeans['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_tf_idf_all_minibatchkmeans['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_tf_idf_all_minibatchkmeans['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_tf_idf_all_minibatchkmeans['layer_4'], 'c')
ax.set_title('Homogeneity TF-IDF All')
ax = axs[4, 2]
ax.plot(range(1, 150, 5), completness_measures_df_tf_idf_all_minibatchkmeans['layer_1'], 'r', range(1, 150, 5), completness_measures_df_tf_idf_all_minibatchkmeans['layer_2'], 'b', range(1, 150, 5), completness_measures_df_tf_idf_all_minibatchkmeans['layer_3'], 'g', range(1, 150, 5), completness_measures_df_tf_idf_all_minibatchkmeans['layer_4'], 'c')
ax.set_title('Completeness TF-IDF All')


# plt.show()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

labels = ["Layer_1", "Layer_2", "Layer_3", "Layer_4"] 
fig.legend(ax, labels=labels, 
           loc="upper right") 

y=np.arange(0, 1, step=0.1)
for i in range(5):
    for j in range(3):
        axs[i, j].axvline(x = 19, color = 'red', linestyle = '--', alpha = 0.5)
        axs[i, j].axvline(x = 124, color = 'blue', linestyle = '--', alpha = 0.5)
        plt.yticks(y)

plt.yticks(y)
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# /tmp/ipykernel_4729/802086528.py:74: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(ax, labels=labels,

# %% [markdown]
# # Word Embedding, SBERT

# %%
# plt.subplots(3, 3, figsize=(12, 12))
fig, axs =  plt.subplots(4, 3, figsize=(15, 10)) # 3 * 9


# Sentence Transformers, Word Embedding
## Distil V1
ax = axs[0, 0]
ax.plot(range(1, 150, 5), v_measures_df_distil_v1pd['layer_1'], 'r', range(1, 150, 5), v_measures_df_distil_v1pd['layer_2'], 'b', range(1, 150, 5), v_measures_df_distil_v1pd['layer_3'], 'g', range(1, 150, 5), v_measures_df_distil_v1pd['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Distil V1')
ax = axs[0, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_distil_v1pd['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_distil_v1pd['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_distil_v1pd['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_distil_v1pd['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Distil V1')
ax = axs[0, 2]
ax.plot(range(1, 150, 5), completness_measures_df_distil_v1pd['layer_1'], 'r', range(1, 150, 5), completness_measures_df_distil_v1pd['layer_2'], 'b', range(1, 150, 5), completness_measures_df_distil_v1pd['layer_3'], 'g', range(1, 150, 5), completness_measures_df_distil_v1pd['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Distil V1')

## Distil V2
ax = axs[1, 0]
ax.plot(range(1, 150, 5), v_measures_df_distil_v2pd['layer_1'], 'r', range(1, 150, 5), v_measures_df_distil_v2pd['layer_2'], 'b', range(1, 150, 5), v_measures_df_distil_v2pd['layer_3'], 'g', range(1, 150, 5), v_measures_df_distil_v2pd['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Distil V2')
ax = axs[1, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_distil_v2pd['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_distil_v2pd['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_distil_v2pd['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_distil_v2pd['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Distil V2')
ax = axs[1, 2]
ax.plot(range(1, 150, 5), completness_measures_df_distil_v2pd['layer_1'], 'r', range(1, 150, 5), completness_measures_df_distil_v2pd['layer_2'], 'b', range(1, 150, 5), completness_measures_df_distil_v2pd['layer_3'], 'g', range(1, 150, 5), completness_measures_df_distil_v2pd['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Distil V2')

## Paraph MiniLM
ax = axs[2, 0]
ax.plot(range(1, 150, 5), v_measures_df_paraph_miniLMpd['layer_1'], 'r', range(1, 150, 5), v_measures_df_paraph_miniLMpd['layer_2'], 'b', range(1, 150, 5), v_measures_df_paraph_miniLMpd['layer_3'], 'g', range(1, 150, 5), v_measures_df_paraph_miniLMpd['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Paraph MiniLM')
ax = axs[2, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_paraph_miniLMpd['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_paraph_miniLMpd['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_paraph_miniLMpd['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_paraph_miniLMpd['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Paraph MiniLM')
ax = axs[2, 2]
ax.plot(range(1, 150, 5), completness_measures_df_paraph_miniLMpd['layer_1'], 'r', range(1, 150, 5), completness_measures_df_paraph_miniLMpd['layer_2'], 'b', range(1, 150, 5), completness_measures_df_paraph_miniLMpd['layer_3'], 'g', range(1, 150, 5), completness_measures_df_paraph_miniLMpd['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Paraph MiniLM')

## Paraph MPNet
ax = axs[3, 0]
ax.plot(range(1, 150, 5), v_measures_df_paraph_mpnetpd['layer_1'], 'r', range(1, 150, 5), v_measures_df_paraph_mpnetpd['layer_2'], 'b', range(1, 150, 5), v_measures_df_paraph_mpnetpd['layer_3'], 'g', range(1, 150, 5), v_measures_df_paraph_mpnetpd['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Paraph MPNet')
ax = axs[3, 1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_paraph_mpnetpd['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_paraph_mpnetpd['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_paraph_mpnetpd['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_paraph_mpnetpd['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Paraph MPNet')
ax = axs[3, 2]
ax.plot(range(1, 150, 5), completness_measures_df_paraph_mpnetpd['layer_1'], 'r', range(1, 150, 5), completness_measures_df_paraph_mpnetpd['layer_2'], 'b', range(1, 150, 5), completness_measures_df_paraph_mpnetpd['layer_3'], 'g', range(1, 150, 5), completness_measures_df_paraph_mpnetpd['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Paraph MPNet')


# plt.show()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

labels = ["Layer_1", "Layer_2", "Layer_3", "Layer_4"] 
fig.legend(ax, labels=labels, 
           loc="upper right") 

y=np.arange(0, 1, step=0.1)
for i in range(4):
    for j in range(3):
        axs[i, j].axvline(x = 19, color = 'red', linestyle = '--', alpha = 0.5)
        axs[i, j].axvline(x = 124, color = 'blue', linestyle = '--', alpha = 0.5)
        plt.yticks(y)

plt.yticks(y)
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# /tmp/ipykernel_100/2226945122.py:60: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(ax, labels=labels,

# %%
# plt.subplots(3, 3, figsize=(12, 12))
fig, axs =  plt.subplots(1, 3, figsize=(15, 3)) # 3 * 9

# One Hot Encoding
ax = axs[0]
ax.plot(range(1, 150, 5), v_measures_df_ohe_key['layer_1'], 'r', range(1, 150, 5), v_measures_df_ohe_key['layer_2'], 'b', range(1, 150, 5), v_measures_df_ohe_key['layer_3'], 'g', range(1, 150, 5), v_measures_df_ohe_key['layer_4'], 'c')
ax.set_title('V-measure OHE', pad=10)
ax.set_xlabel("Number of K's")
ax = axs[1]
ax.plot(range(1, 150, 5), homogeneity_measures_df_ohe_key['layer_1'], 'r', range(1, 150, 5), homogeneity_measures_df_ohe_key['layer_2'], 'b', range(1, 150, 5), homogeneity_measures_df_ohe_key['layer_3'], 'g', range(1, 150, 5), homogeneity_measures_df_ohe_key['layer_4'], 'c')
ax.set_title('Homogeneity OHE', pad=10)
ax.set_xlabel("Number of K's")
ax = axs[2]
ax.plot(range(1, 150, 5), completness_measures_df_ohe_key['layer_1'], 'r', range(1, 150, 5), completness_measures_df_ohe_key['layer_2'], 'b', range(1, 150, 5), completness_measures_df_ohe_key['layer_3'], 'g', range(1, 150, 5), completness_measures_df_ohe_key['layer_4'], 'c')
ax.set_title('Completeness OHE', pad=10)
ax.set_xlabel("Number of K's")


# plt.show()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

labels = ["Layer_1", "Layer_2", "Layer_3", "Layer_4"] 
fig.legend(ax, labels=labels, 
           loc="upper right") 

y=np.arange(0, 1, step=0.1)
# for i in range(1):
for j in range(3):
    axs[j].axvline(x = 19, color = 'red', linestyle = '--', alpha = 0.5)
    axs[j].axvline(x = 124, color = 'blue', linestyle = '--', alpha = 0.5)
    plt.yticks(y)

plt.yticks(y)
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# /tmp/ipykernel_100/1001551695.py:28: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(ax, labels=labels,

# %% [markdown]
# # SSE

# %% [markdown]
# TF_IDF

# %%
fig, axs =  plt.subplots(2, 4, figsize=(20, 8)) # 3 * 9
from matplotlib import gridspec

ax1 = axs[0, 0]
ax1.plot(range(1, 150, 5), sse_bezeichnung)

ax2 = axs[0, 1]
ax2.plot(range(1, 150, 5), sse_webbezeichnung)

ax3 = axs[0, 2]
ax3.plot(range(1, 150, 5), sse_detail)

ax4 = axs[0, 3]
ax4.plot(range(1, 150, 5), sse_lieferanten)

ax5 = axs[1, 0]
ax5.plot(range(1, 150, 5), sse_all)

ax6 = axs[1, 1]
ax6.set_axis_off()
ax7 = axs[1, 2]
ax7.set_axis_off()
ax8 = axs[1, 3]
ax8.set_axis_off()

# fig.suptitle('The elbow method for TF-IDF text representation')
fig.supxlabel('Number of clusters')
fig.supylabel('WCSS')

plt.show()

# %% [markdown]
# Sentence Transformer

# %%
fig, axs =  plt.subplots(1, 4, figsize=(20, 4)) # 3 * 9


ax = axs[0]
ax.plot(range(1, 150, 5), sse_scaled_distil1)

ax = axs[1]
ax.plot(range(1, 150, 5), sse_scaled_distil2)

ax = axs[2]
ax.plot(range(1, 150, 5), sse_scaled_miniLM)

ax = axs[3]
ax.plot(range(1, 150, 5), sse_scaled_mpnet)

# fig.suptitle('The elbow method for Sentence Transformers word embedding text representation')
fig.supxlabel('Number of clusters')
fig.supylabel('WCSS')

plt.show()

# %% [markdown]
# OHE

# %%
fig, axs =  plt.subplots(1, 1, figsize=(6, 6)) # 3 * 9

# ax = axs[0]
axs.plot(range(1, 150, 5), sse_OHE)
# fig.suptitle('The elbow method OHE text representation')
fig.supxlabel('Number of clusters')
fig.supylabel('WCSS')

plt.show()

# %% [markdown]
# # Plotting the HDBSCAN results of SBERT
#
# (the hdbscan algorithm crashed while running the other two text representation, due to their large size
# and sparsity of the matrices. The sparsity of the matrices caused the hdbscan to use the "Brute" algorithm,
# which has a high space and time complexity.)

# %%
# plt.subplots(3, 3, figsize=(12, 12))
fig, axs =  plt.subplots(4, 3, figsize=(15, 10)) # 3 * 9
x_values = [0.01, 0.1, 0.5]

# Sentence Transformers, Word Embedding
## Distil V1
ax = axs[0, 0]
ax.plot(x_values, v_measures_df_paraph_distil1['layer_1'], 'r',
        x_values, v_measures_df_paraph_distil1['layer_2'], 'b', 
        x_values, v_measures_df_paraph_distil1['layer_3'], 'g', 
        x_values, v_measures_df_paraph_distil1['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Distil V1')

ax = axs[0, 1]
ax.plot(x_values, homogeneity_measures_df_paraph_distil1['layer_1'], 'r', 
        x_values, homogeneity_measures_df_paraph_distil1['layer_2'], 'b', 
        x_values, homogeneity_measures_df_paraph_distil1['layer_3'], 'g', 
        x_values, homogeneity_measures_df_paraph_distil1['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Distil V1')

ax = axs[0, 2]
ax.plot(x_values, completness_measures_df_paraph_distil1['layer_1'], 'r', 
        x_values, completness_measures_df_paraph_distil1['layer_2'], 'b', 
        x_values, completness_measures_df_paraph_distil1['layer_3'], 'g', 
        x_values, completness_measures_df_paraph_distil1['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Distil V1')

## Distil V2
ax = axs[1, 0]
ax.plot(x_values, v_measures_df_paraph_distil2['layer_1'], 'r', 
        x_values, v_measures_df_paraph_distil2['layer_2'], 'b', 
        x_values, v_measures_df_paraph_distil2['layer_3'], 'g', 
        x_values, v_measures_df_paraph_distil2['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Distil V2')
ax = axs[1, 1]
ax.plot(x_values, homogeneity_measures_df_paraph_distil2['layer_1'], 'r', 
        x_values, homogeneity_measures_df_paraph_distil2['layer_2'], 'b', 
        x_values, homogeneity_measures_df_paraph_distil2['layer_3'], 'g', 
        x_values, homogeneity_measures_df_paraph_distil2['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Distil V2')
ax = axs[1, 2]
ax.plot(x_values, completness_measures_df_paraph_distil2['layer_1'], 'r', 
        x_values, completness_measures_df_paraph_distil2['layer_2'], 'b', 
        x_values, completness_measures_df_paraph_distil2['layer_3'], 'g', 
        x_values, completness_measures_df_paraph_distil2['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Distil V2')

## Paraph MiniLM
ax = axs[2, 0]
ax.plot(x_values, v_measures_df_paraph_minlm['layer_1'], 'r', 
        x_values, v_measures_df_paraph_minlm['layer_2'], 'b', 
        x_values, v_measures_df_paraph_minlm['layer_3'], 'g', 
        x_values, v_measures_df_paraph_minlm['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Paraph MiniLM')

ax = axs[2, 1]
ax.plot(x_values, homogeneity_measures_df_paraph_minilm['layer_1'], 'r', 
        x_values, homogeneity_measures_df_paraph_minilm['layer_2'], 'b', 
        x_values, homogeneity_measures_df_paraph_minilm['layer_3'], 'g', 
        x_values, homogeneity_measures_df_paraph_minilm['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Paraph MiniLM')
ax = axs[2, 2]
ax.plot(x_values, completness_measures_df_paraph_minilm['layer_1'], 'r', 
        x_values, completness_measures_df_paraph_minilm['layer_2'], 'b', 
        x_values, completness_measures_df_paraph_minilm['layer_3'], 'g', 
        x_values, completness_measures_df_paraph_minilm['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Paraph MiniLM')

## Paraph MPNet
ax = axs[3, 0]
ax.plot(x_values, v_measures_df_mpnet['layer_1'], 'r', 
        x_values, v_measures_df_mpnet['layer_2'], 'b', 
        x_values, v_measures_df_mpnet['layer_3'], 'g', 
        x_values, v_measures_df_mpnet['layer_4'], 'c')
ax.set_title('V-measure SentenceTransformers Paraph MPNet')
ax = axs[3, 1]
ax.plot(x_values, homogeneity_measures_df_mpnet['layer_1'], 'r', 
        x_values, homogeneity_measures_df_mpnet['layer_2'], 'b', 
        x_values, homogeneity_measures_df_mpnet['layer_3'], 'g', 
        x_values, homogeneity_measures_df_mpnet['layer_4'], 'c')
ax.set_title('Homogeneity SentenceTransformers Paraph MPNet')
ax = axs[3, 2]
ax.plot(x_values, completness_measures_df_mpnet['layer_1'], 'r', 
        x_values, completness_measures_df_mpnet['layer_2'], 'b', 
        x_values, completness_measures_df_mpnet['layer_3'], 'g', 
        x_values, completness_measures_df_mpnet['layer_4'], 'c')
ax.set_title('Completeness SentenceTransformers Paraph MPNet')


# plt.show()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

labels = ["Layer_1", "Layer_2", "Layer_3", "Layer_4"] 
fig.legend(ax, labels=labels, 
           loc="upper right") 


plt.yticks(y)
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# /tmp/ipykernel_81/248519605.py:99: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(ax, labels=labels,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 103
#      98 labels = ["Layer_1", "Layer_2", "Layer_3", "Layer_4"]
#      99 fig.legend(ax, labels=labels,
#     100            loc="upper right")
# --> 103 plt.yticks(y)
#     104 plt.tight_layout()
#     106 # Show the plots
#
# NameError: name 'y' is not defined
